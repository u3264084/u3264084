# %% [markdown]
# # Problem: Predicting Airplane Delays
#
# The goals of this notebook are:
# - Process and create a dataset from downloaded ZIP files
# - Exploratory data analysis (EDA)
# - Establish a baseline model and improve it
#
# ## Introduction to business scenario
# You work for a travel booking website that is working to improve the customer experience for flights that were delayed. The company wants to create a feature to let customers know if the flight will be delayed due to weather when the customers are booking the flight to or from the busiest airports for domestic travel in the US.
#
# You are tasked with solving part of this problem by leveraging machine learning to identify whether the flight will be delayed due to weather. You have been given access to the a dataset of on-time performance of domestic flights operated by large air carriers. You can use this data to train a machine learning model to predict if the flight is going to be delayed for the busiest airports.
#
# ### Dataset
# The provided dataset contains scheduled and actual departure and arrival times reported by certified US air carriers that account for at least 1 percent of domestic scheduled passenger revenues. The data was collected by the Office of Airline Information, Bureau of Transportation Statistics (BTS). The dataset contains date, time, origin, destination, airline, distance, and delay status of flights for flights between 2014 and 2018.
# The data are in 60 compressed files, where each file contains a CSV for the flight details in a month for the five years (from 2014 - 2018). The data can be downloaded from this [link](https://ucstaff-my.sharepoint.com/:f:/g/personal/ibrahim_radwan_canberra_edu_au/Er0nVreXmihEmtMz5qC5kVIB81-ugSusExPYdcyQTglfLg?e=bNO312). Please download the data files and place them on a relative path. Dataset(s) used in this assignment were compiled by the Office of Airline Information, Bureau of Transportation Statistics (BTS), Airline On-Time Performance Data, available with the following [link](https://www.transtats.bts.gov/Fields.asp?gnoyr_VQ=FGJ).

# %% [markdown]
# # Step 1: Prepare the environment
#
# Use one of the labs which we have practised on with the Amazon Sagemakers where you perform the following steps:
# 1. Start a lab.
# 2. Create a notebook instance and name it "oncloudproject".
# 3. Increase the used memory to 25 GB from the additional configurations.
# 4. Open Jupyter Lab and upload this notebook into it.
# 5. Upload the two combined CVS files (combined_csv_v1.csv and combined_csv_v2.csv), which you created in Part A of this project.

# %% [markdown]
# # Step 2: Build and evaluate simple models
#
# Write code to perform the follwoing steps:
# 1. Split data into training, validation and testing sets (70% - 15% - 15%).
# 2. Use linear learner estimator to build a classifcation model.
# 3. Host the model on another instance
# 4. Perform batch transform to evaluate the model on testing data
# 5. Report the performance metrics that you see better test the model performance
#
# Note: You are required to perform the above steps on the two combined datasets separatey and to comments on the difference.

# %%
#installing boto3 sagemaker
# !pip install boto3 sagemaker

import pandas as pd
import boto3
import io
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import sagemaker
from sagemaker import get_execution_role

# Create a SageMaker session
sess = sagemaker.Session()

# Define IAM role
role = get_execution_role()
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.12.3 requires botocore<1.34.70,>=1.34.41, but you have botocore 1.35.51 which is incompatible.
# Collecting boto3
#   Downloading boto3-1.35.51-py3-none-any.whl.metadata (6.7 kB)
# Collecting sagemaker
#   Downloading sagemaker-2.232.2-py3-none-any.whl.metadata (16 kB)
# Collecting botocore<1.36.0,>=1.35.51 (from boto3)
#   Downloading botocore-1.35.51-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\tandi\anaconda3\lib\site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: attrs<24,>=23.1.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (23.1.0)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (2.2.1)
# Collecting docker (from sagemaker)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting google-pasta (from sagemaker)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonschema in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (4.19.2)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (23.2)
# Requirement already satisfied: pandas in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (2.2.2)
# Collecting pathos (from sagemaker)
#   Downloading pathos-0.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (3.10.0)
# Requirement already satisfied: protobuf<5.0,>=3.12 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (3.20.3)
# Requirement already satisfied: psutil in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (5.9.0)
# Requirement already satisfied: pyyaml~=6.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (6.0.1)
# Requirement already satisfied: requests in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (2.32.2)
# Collecting sagemaker-core<2.0.0,>=1.0.0 (from sagemaker)
#   Downloading sagemaker_core-1.0.10-py3-none-any.whl.metadata (4.9 kB)
# Collecting sagemaker-mlflow (from sagemaker)
#   Downloading sagemaker_mlflow-0.1.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting schema (from sagemaker)
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Collecting smdebug-rulesconfig==1.0.1 (from sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: tblib<4,>=1.7.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (1.7.0)
# Requirement already satisfied: tqdm in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (4.66.4)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker) (2.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\tandi\anaconda3\lib\site-packages (from botocore<1.36.0,>=1.35.51->boto3) (2.9.0.post0)
# Requirement already satisfied: zipp>=0.5 in c:\users\tandi\anaconda3\lib\site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.17.0)
# Requirement already satisfied: pydantic<3.0.0,>=1.7.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.5.3)
# Collecting platformdirs (from sagemaker)
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in c:\users\tandi\anaconda3\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker) (13.3.5)
# Collecting mock<5.0,>4.0 (from sagemaker-core<2.0.0,>=1.0.0->sagemaker)
#   Downloading mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tandi\anaconda3\lib\site-packages (from jsonschema->sagemaker) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tandi\anaconda3\lib\site-packages (from jsonschema->sagemaker) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tandi\anaconda3\lib\site-packages (from jsonschema->sagemaker) (0.10.6)
# Requirement already satisfied: pywin32>=304 in c:\users\tandi\anaconda3\lib\site-packages (from docker->sagemaker) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tandi\anaconda3\lib\site-packages (from requests->sagemaker) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tandi\anaconda3\lib\site-packages (from requests->sagemaker) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tandi\anaconda3\lib\site-packages (from requests->sagemaker) (2024.8.30)
# Requirement already satisfied: six in c:\users\tandi\anaconda3\lib\site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tandi\anaconda3\lib\site-packages (from pandas->sagemaker) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tandi\anaconda3\lib\site-packages (from pandas->sagemaker) (2023.3)
# Collecting ppft>=1.7.6.9 (from pathos->sagemaker)
#   Downloading ppft-1.7.6.9-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.9 (from pathos->sagemaker)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.5 (from pathos->sagemaker)
#   Downloading pox-0.3.5-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.17 (from pathos->sagemaker)
#   Downloading multiprocess-0.70.17-py312-none-any.whl.metadata (7.2 kB)
# Collecting mlflow>=2.8 (from sagemaker-mlflow->sagemaker)
#   Downloading mlflow-2.17.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: colorama in c:\users\tandi\anaconda3\lib\site-packages (from tqdm->sagemaker) (0.4.6)
# Collecting mlflow-skinny==2.17.1 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading mlflow_skinny-2.17.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: Flask<4 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.3)
# Collecting alembic!=1.10.0,<2 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting graphene<4 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading graphene-3.4.1-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.8.4)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (14.0.2)
# Requirement already satisfied: scikit-learn<2 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.2)
# Requirement already satisfied: scipy<2 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.0.30)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.4)
# Collecting waitress<4 (from mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading waitress-3.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (8.1.7)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading databricks_sdk-0.36.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\tandi\anaconda3\lib\site-packages (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.1.37)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\tandi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\tandi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\tandi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=1.7.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\tandi\anaconda3\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tandi\anaconda3\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (2.15.1)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\tandi\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\tandi\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\tandi\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.6.2)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading graphql_core-3.2.5-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tandi\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tandi\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker) (0.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tandi\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tandi\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tandi\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tandi\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\tandi\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tandi\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.9)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tandi\anaconda3\lib\site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tandi\anaconda3\lib\site-packages (from scikit-learn<2->mlflow>=2.8->sagemaker-mlflow->sagemaker) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\tandi\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.8->sagemaker-mlflow->sagemaker) (3.0.1)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tandi\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.0.7)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\tandi\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (1.14.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\tandi\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tandi\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tandi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.1->mlflow>=2.8->sagemaker-mlflow->sagemaker) (0.4.8)
# Downloading boto3-1.35.51-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    -------------------------------------- - 133.1/139.2 kB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 139.2/139.2 kB 2.7 MB/s eta 0:00:00
# Downloading sagemaker-2.232.2-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.6 MB 11.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.6 MB 5.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.6 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 1.4/1.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 7.1 MB/s eta 0:00:00
# Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Downloading botocore-1.35.51-py3-none-any.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 7.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.6 MB 20.6 MB/s eta 0:00:01
#    ------- -------------------------------- 2.5/12.6 MB 16.1 MB/s eta 0:00:01
#    --------- ------------------------------ 3.1/12.6 MB 13.9 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.6 MB 19.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.3/12.6 MB 17.7 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.6 MB 22.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 21.5 MB/s eta 0:00:01
#    ------------------------------ --------- 9.5/12.6 MB 21.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.4/12.6 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.9/12.6 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 8.0 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading s3transfer-0.10.3-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.6 kB ? eta -:--:--
#    ---------------------------------------- 82.6/82.6 kB ? eta 0:00:00
# Downloading sagemaker_core-1.0.10-py3-none-any.whl (388 kB)
#    ---------------------------------------- 0.0/388.4 kB ? eta -:--:--
#    ---------------------------------------  378.9/388.4 kB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 388.4/388.4 kB 8.0 MB/s eta 0:00:00
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.8 kB ? eta -:--:--
#    ---------------------------------------- 147.8/147.8 kB 4.4 MB/s eta 0:00:00
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#    ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Downloading pathos-0.3.3-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.1 kB ? eta -:--:--
#    ---------------------------------------- 82.1/82.1 kB ? eta 0:00:00
# Downloading sagemaker_mlflow-0.1.0-py3-none-any.whl (24 kB)
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.4 kB ? eta -:--:--
#    ---------------------------------------- 119.4/119.4 kB 7.3 MB/s eta 0:00:00
# Downloading mlflow-2.17.1-py3-none-any.whl (26.7 MB)
#    ---------------------------------------- 0.0/26.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/26.7 MB 10.2 MB/s eta 0:00:03
#     --------------------------------------- 0.3/26.7 MB 10.2 MB/s eta 0:00:03
#    -- ------------------------------------- 1.8/26.7 MB 14.6 MB/s eta 0:00:02
#    --- ------------------------------------ 2.5/26.7 MB 13.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.7/26.7 MB 19.6 MB/s eta 0:00:02
#    -------- ------------------------------- 5.7/26.7 MB 21.5 MB/s eta 0:00:01
#    --------- ------------------------------ 6.5/26.7 MB 20.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 7.8/26.7 MB 22.7 MB/s eta 0:00:01
#    --------------- ------------------------ 10.4/26.7 MB 24.2 MB/s eta 0:00:01
#    ------------------- -------------------- 12.9/26.7 MB 38.6 MB/s eta 0:00:01
#    --------------------- ------------------ 14.6/26.7 MB 38.6 MB/s eta 0:00:01
#    --------------------- ------------------ 14.6/26.7 MB 36.4 MB/s eta 0:00:01
#    --------------------- ------------------ 14.6/26.7 MB 36.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.7/26.7 MB 26.2 MB/s eta 0:00:01
#    ------------------------- -------------- 16.9/26.7 MB 28.4 MB/s eta 0:00:01
#    -------------------------------- ------- 21.7/26.7 MB 34.4 MB/s eta 0:00:01
#    --------------------------------- ------ 22.2/26.7 MB 32.8 MB/s eta 0:00:01
#    --------------------------------- ------ 22.4/26.7 MB 28.4 MB/s eta 0:00:01
#    ------------------------------------- -- 25.2/26.7 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  26.7/26.7 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  26.7/26.7 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  26.7/26.7 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------- 26.7/26.7 MB 29.7 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.17.1-py3-none-any.whl (5.7 MB)
#    ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#    ------------------------- -------------- 3.6/5.7 MB 46.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.7/5.7 MB 51.8 MB/s eta 0:00:00
# Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.17-py312-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/148.0 kB ? eta -:--:--
#    ---------------------------------------- 148.0/148.0 kB 8.6 MB/s eta 0:00:00
# Downloading pox-0.3.5-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.9-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.2 kB ? eta -:--:--
#    --------------------------------- ------ 194.6/233.2 kB ? eta -:--:--
#    ---------------------------------------- 233.2/233.2 kB 4.7 MB/s eta 0:00:00
# Downloading graphene-3.4.1-py2.py3-none-any.whl (114 kB)
#    ---------------------------------------- 0.0/114.7 kB ? eta -:--:--
#    ---------------------------------------- 114.7/114.7 kB 3.4 MB/s eta 0:00:00
# Downloading waitress-3.0.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.7 kB ? eta -:--:--
#    ---------------------------------------- 56.7/56.7 kB ? eta 0:00:00
# Downloading databricks_sdk-0.36.0-py3-none-any.whl (569 kB)
#    ---------------------------------------- 0.0/569.1 kB ? eta -:--:--
#    ------------- -------------------------- 194.6/569.1 kB 5.9 MB/s eta 0:00:01
#    --------------------------------------- 569.1/569.1 kB 11.9 MB/s eta 0:00:00
# Downloading graphql_core-3.2.5-py3-none-any.whl (203 kB)
#    ---------------------------------------- 0.0/203.2 kB ? eta -:--:--
#    --------------------------------------- 203.2/203.2 kB 12.9 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/64.0 kB ? eta -:--:--
#    ---------------------------------------- 64.0/64.0 kB 3.6 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#    ---------------------------------------- 0.0/110.5 kB ? eta -:--:--
#    ---------------------------------------- 110.5/110.5 kB 3.2 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#    ---------------------------------------- 0.0/149.7 kB ? eta -:--:--
#    -------------------------------------- - 143.4/149.7 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 149.7/149.7 kB 3.0 MB/s eta 0:00:00
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.2 kB ? eta -:--:--
#    ---------------------------------------- 44.2/44.2 kB 2.1 MB/s eta 0:00:00
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 4.3 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
#    ---------------------------------------- 0.0/209.0 kB ? eta -:--:--
#    --------------------------------------- 209.0/209.0 kB 13.2 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Installing collected packages: schema, waitress, sqlparse, smdebug-rulesconfig, rsa, ppft, pox, platformdirs, mock, Mako, importlib-metadata, graphql-core, google-pasta, dill, deprecated, opentelemetry-api, multiprocess, graphql-relay, google-auth, docker, botocore, alembic, s3transfer, pathos, opentelemetry-semantic-conventions, graphene, databricks-sdk, opentelemetry-sdk, boto3, sagemaker-core, mlflow-skinny, mlflow, sagemaker-mlflow, sagemaker
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.10.0
#     Uninstalling platformdirs-3.10.0:
#       Successfully uninstalled platformdirs-3.10.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.69
#     Uninstalling botocore-1.34.69:
#       Successfully uninstalled botocore-1.34.69
# Successfully installed Mako-1.3.6 alembic-1.13.3 boto3-1.35.51 botocore-1.35.51 databricks-sdk-0.36.0 deprecated-1.2.14 dill-0.3.9 docker-7.1.0 google-auth-2.35.0 google-pasta-0.2.0 graphene-3.4.1 graphql-core-3.2.5 graphql-relay-3.2.0 importlib-metadata-6.11.0 mlflow-2.17.1 mlflow-skinny-2.17.1 mock-4.0.3 multiprocess-0.70.17 opentelemetry-api-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 pathos-0.3.3 platformdirs-4.3.6 pox-0.3.5 ppft-1.7.6.9 rsa-4.9 s3transfer-0.10.3 sagemaker-2.232.2 sagemaker-core-1.0.10 sagemaker-mlflow-0.1.0 schema-0.7.7 smdebug-rulesconfig-1.0.1 sqlparse-0.5.1 waitress-3.0.1
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\tandi\AppData\Local\sagemaker\sagemaker\config.yaml
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 14
#      11 from sagemaker import get_execution_role
#      13 # Create a SageMaker session
# ---> 14 sess = sagemaker.Session()
#      16 # Define IAM role
#      17 role = get_execution_role()
#
# File ~\anaconda3\Lib\site-packages\sagemaker\session.py:265, in Session.__init__(self, boto_session, sagemaker_client, sagemaker_runtime_client, sagemaker_featurestore_runtime_client, default_bucket, settings, sagemaker_metrics_client, sagemaker_config, default_bucket_prefix)
#     262 self.lambda_client = None
#     263 self.settings = settings if settings else SessionSettings()
# --> 265 self._initialize(
#     266     boto_session=boto_session,
#     267     sagemaker_client=sagemaker_client,
#     268     sagemaker_runtime_client=sagemaker_runtime_client,
#     269     sagemaker_featurestore_runtime_client=sagemaker_featurestore_runtime_client,
#     270     sagemaker_metrics_client=sagemaker_metrics_client,
#     271     sagemaker_config=sagemaker_config,
#     272 )
#
# File ~\anaconda3\Lib\site-packages\sagemaker\session.py:293, in Session._initialize(self, boto_session, sagemaker_client, sagemaker_runtime_client, sagemaker_featurestore_runtime_client, sagemaker_metrics_client, sagemaker_config)
#     291 self._region_name = self.boto_session.region_name
#     292 if self._region_name is None:
# --> 293     raise ValueError(
#     294         "Must setup local AWS configuration with a region supported by SageMaker."
#     295     )
#     297 # Make use of user_agent_extra field of the botocore_config object
#     298 # to append SageMaker Python SDK specific user_agent suffix
#     299 # to the current User-Agent header value from boto3
#     300 # This config will also make sure that user_agent never fails to log the User-Agent string
#     301 # even if boto User-Agent header format is updated in the future
#     302 # Ref: https://botocore.amazonaws.com/v1/documentation/api/latest/reference/config.html
#     303 botocore_config = botocore.config.Config(user_agent_extra=get_user_agent_extra_suffix())
#
# ValueError: Must setup local AWS configuration with a region supported by SageMaker.

# %%
df = pd.read_csv(r'C:\Users\tandi\DSTS\assign 2\data_compressed.csv')  
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\tandi\DSTS\assign 2\data_compressed.csv')
#       2 print(df.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\tandi\\DSTS\\assign 2\\data_compressed.csv'

# %%
# Write the final comments here and turn the cell type into markdown

# %% [markdown]
# # Step 3: Build and evaluate ensembe models
#
# Write code to perform the follwoing steps:
# 1. Split data into training, validation and testing sets (70% - 15% - 15%).
# 2. Use xgboost estimator to build a classifcation model.
# 3. Host the model on another instance
# 4. Perform batch transform to evaluate the model on testing data
# 5. Report the performance metrics that you see better test the model performance
# 6. write down your observation on the difference between the performance of using the simple and ensemble models.
# Note: You are required to perform the above steps on the two combined datasets separatey.

# %%
# Write the code here and add cells as you need

# %%
# Write the final comments here and turn the cell type into markdown
